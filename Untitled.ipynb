# %%
from functions import fetch_data

# %%
df = fetch_data('aapl_df')

# %%
df['price'] = df[['high', 'low']].mean(axis=1)

# %%
df['mean'] = df['price'].rolling(window=91, center=True, min_periods=1).mean()

# %%
df[['price', 'mean']].plot()#loc[0:200].plot()
# Out:
# <AxesSubplot:>

# %%
df['noise'] = (df['mean']-df['price'])**2

# %%
df['noise'].plot()
# Out:
# <AxesSubplot:>

# %%
df['diff'] =
